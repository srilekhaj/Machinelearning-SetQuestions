# %%
#1.
from sklearn.preprocessing import LabelEncoder
df['gender'] = LabelEncoder().fit_transform(df.gender)
df = pd.get_dummies(df, columns=['gender'])

# %%
NameError df and pd are not defined

# %%
#2.
from sklearn.tree import DecisionTreeClassifier

y = ['yes', 'no', 'yes', 'no']
model = DecisionTreeClassifier()
model.fit(X, y)

# %%
NameError: name 'X' is not defined

# %%
#3.
X = data.drop('Purchased', axis=1)
y = data['Purchased']
X = X.drop('Purchased', axis=1)

# %%
NameError: name 'data' is not defined

# %%
#4.
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(max_depth=None)  
model.fit(X, y)

model.score(X, y)

# %%
NameError: name 'X' is not defined
NameError: name 'y' is not defined

# %%
#5.
from sklearn.preprocessing import MinMaxScaler
import numpy as np

data = [[-1, 2], [0, 0], [1, 2]]
scaler = MinMaxScaler()
scaler.fit(data)
print(scaler.transform())

# %%
TypeError
transform() requires an argument to be passed inside the function parentheses.
print(scaler.transform(data))

# %%
#6.
from sklearn.metrics import accuracy_score

y_true = [1, 0, 1]
y_pred = [1, 1, 0]

acc = accuracy_score()
print("Accuracy:", acc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       4 y_true = [1, 0, 1]
#       5 y_pred = [1, 1, 0]
# ----> 7 acc = accuracy_score()
#       8 print("Accuracy:", acc)
#
# File c:\Users\jsril\anaconda3\envs\dl_env\Lib\site-packages\sklearn\utils\_param_validation.py:196, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
# --> 196 params = func_sig.bind(*args, **kwargs)
#     197 params.apply_defaults()
#     199 # ignore self/cls and positional/keyword markers
#
# File c:\Users\jsril\anaconda3\envs\dl_env\Lib\inspect.py:3280, in Signature.bind(self, *args, **kwargs)
#    3275 def bind(self, /, *args, **kwargs):
#    3276     """Get a BoundArguments object, that maps the passed `args`
# ...

# %%
TypeError missing 2 required positional arguments: 'y_true' and 'y_pred'
acc = accuracy_score(y_true, y_pred)
acc
# Out:
# 0.3333333333333333

# %%
#7.
from sklearn.model_selection import train_test_split
import numpy as np

X = np.array([[1, 2], [3, 4], [5, 6]])
y = np.array([0, 1])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
ValueError: The length of y (2) does not match the number of samples in X (3)

# %%
#8.
import pandas as pd

df = pd.DataFrame({
    'Feature': ['1', '2', 'three']
})

df['Feature'] = df['Feature'].astype(int)

# %%
#9
from sklearn.tree import DecisionTreeClassifier

X = [[1, 2], [3, 4], [5, 6]]
y = ['yes', 'no'] 
clf = DecisionTreeClassifier()
clf.fit(X, y)

# %%
#10.
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression

iris = load_iris()
X, y = iris.data, iris.target

model = LogisticRegression()
model.fit(X, y)
print(model.predict_proba([[5.1, 3.5]]))
