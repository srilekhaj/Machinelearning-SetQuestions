# %%
#1.The following code throws an error. What is wrong?
import tensorflow as tf
model = keras.Sequential()  # Error here

# %%
NameError: name 'keras' is not defined

# %%
#2.
from sklearn.svm import SVC
from sklearn.datasets import load_diabetes

X, y = load_diabetes(return_X_y=True)

model = SVC()
model.fit(X, y)  # Error

# %%
#3.
from sklearn.tree import RandomForestClassifier  # Incorrect import
clf = RandomForestClassifier()

# %%
ImportError: cannot import name 'RandomForestClassifier' from 'sklearn.tree'

from sklearn.ensemble import RandomForestClassifier  # correct import
clf = RandomForestClassifier()

# %%
#4.
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

X = [[1, 2], [3, 4], [5, 6], [7, 8]]
y = [0, 1, 0, 1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)  # Error

# %%
cannot use fit_transform on test data; should use transform instead
X_test = scaler.transform(X_test)  # Corrected code

# %%
#5.
import pandas as pd
df = pd.DataFrame({'age': [25, 30, 35], 'salary': [50000, 60000, 70000]})
print(df['salry'])  # Typo

# %%
KeyError: 'salry'
print(df['salary'])  # Corrected code

# %%
#6.import pandas as pd
df = pd.DataFrame({'Age': ['25', '30', '35']})  # Stored as string
print(df['Age'].mean())

# %%
expects a integer or float value but got String 
TypeError

# %%
#7.
def add_numbers(a, b):
result = a + b
 return result

# %%
IndentationError : expected an indented block
def add_numbers(a, b):
    result = a + b
    return result

# %%
#8.
from sklearn.model_selection import train_test_split
X = [1, 2, 3, 4, 5]
y = [1, 0, 1, 0]  # Mismatched length
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
ValueError : Inconsistent number of samples between X and y

# %%
#9.
print(my_name)
my_name = "Alice"

# %%
NameError : my_name is not defined

my_name is used before assignment

# %%
#10.
import pandas as pd

df = pd.DataFrame({'Age': [25, 30, 35, 40]})
df['Age_Category'] = df['Age'].apply(lambda x: 'Young' if x < 30 'Old')  # Error

# %%
SyntaxError else is missing
